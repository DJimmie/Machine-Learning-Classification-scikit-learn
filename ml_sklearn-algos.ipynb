# %%
import pandas as pd
from pandas import set_option
import numpy as np
from numpy import set_printoptions
import datetime

# import tkinter


# import matplotlib.pyplot as plt
import matplotlib
matplotlib.use("TkAgg")
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg, NavigationToolbar2TkAgg
# Implement the default Matplotlib key bindings.
from matplotlib.backend_bases import key_press_handler
from matplotlib.figure import Figure
from pandas.plotting import scatter_matrix

import tkinter.ttk
from tkinter import filedialog
from tkinter import messagebox
from tkinter import *


import os
import sys
sys.path.insert(0, "C:\\Users\\Crystal\\Desktop\\Programs\\my-modules-and-libraries")

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from scipy import stats

import my_gui_maker as gm
import data_wrangle as dw

# %%
def open_file_dialog():
    """(1-9-2018) Allows user to select dataset using file dialog window. The default directory is the 'dataset_repo'"""
    
    my_path='C:\\Users\\Crystal\\Desktop\\Programs\\dataset_repo'
    x=filedialog.askopenfilename(initialdir = my_path,title = "Data Repository",filetypes = (("all files","*.*"),("jpeg files","*.jpg"))) 
    filename, file_extension = os.path.splitext(x)
    print (filename) 
    print (file_extension)
    
    
    the_filename=filename.split('/')[-1]
    the_path=filename.partition('/'+the_filename)[0]
    the_extension=file_extension.split('.')[-1]
    
    the_file=filename+'.'+the_extension
    print (filename+'.'+the_extension)
    get_data(the_file)

# %%
def get_data (location,names=None):
    """(1-19-2019) Retrieves the data the user selected from the file dialog box. 
    The Data Info frame (f1) is created where the data info is display as a Treeview.
    The dlc frame is created where the data.head() is displayed in list box format."""
#     the_data=pd.read_csv(location,usecols=names)
    
    data=pd.read_csv(location)
#     set_option('precision',3)
    data=data.round(3)

    data_info=dw.data_info(data)
    
    print(data.head(20))
    print(data.info())
    
    data_ops_select(data_info,data)

# %%
def data_ops_select(data_info,data):
    
#     f1=gm.My_Frame(root)
#     f1['bg']='grey'
#     f1.frame_header('Data Info',0,0)
    f1.place_frame(0,0)
    f1.the_tree(2,0,data_info)
    
#     list_by=['Metrics','TBD_1','TBD_2']
#     radioframe=gm.My_Frame(f1)
    radioframe.place_frame(2,2)
#     radioframe.radio_button(list_by,0,0,radio_select_comm)
#     radioframe.radios[0].invoke()
    
    
    dlc=gm.My_Frame(root)
#     dlc.frame_header('Data Head',0,0)
    dlc.my_dlist_canvas(1,0,data.head())
    dlc.place_frame(3,0)

# %%
def radio_select_comm(*args):
    """Takes action based on radiobutton selection."""

#     global your_list
    print(radioframe.var.get())

    x=radioframe.var.get()
    print ('x:',x)

# %%
def bye_bye():
    root.destroy()
#     sys.exit()
#     exit
    root.quit()

# %%
if __name__ == "__main__":
    
    root=gm.my_window(None)
    
    menubar=Menu(root)
    menubar.add_command(label="Get the Data", command=lambda: open_file_dialog())
    menubar.add_command(label="Exit", command=lambda: bye_bye())
    menubar.config(font=("Verdana", 14))
    
    root.config(menu=menubar)
    
    f1=gm.My_Frame(root)
    f1['bg']='grey'
    f1.frame_header('Data Info',0,0)
    
    list_by=['Metrics','TBD_1','TBD_2']
    radioframe=gm.My_Frame(f1)
    radioframe.radio_button(list_by,0,0,radio_select_comm)
#     radioframe.radios[2].invoke()
    
    dlc=gm.My_Frame(root)
    
    root.mainloop()
# Out:
# C:/Users/Crystal/Desktop/Programs/dataset_repo/transactions_01-01-2018_to_02-07-2019
# .csv
# C:/Users/Crystal/Desktop/Programs/dataset_repo/transactions_01-01-2018_to_02-07-2019.csv
#    TRNTYPE    DTPOSTED  TRANAMT                  FITID  \
# 0   CREDIT  01-02-2018    38.68  132676295201801020001
# 1    DEBIT  01-02-2018    -2.00  132676295201801020002
# 2    DEBIT  01-02-2018  -341.11  132676295201801020003
# 3   CREDIT  01-02-2018     0.01  132676295201801020004
# 4   CREDIT  01-02-2018    50.55  132676295201801020005
# 5    DEBIT  01-02-2018   -48.56  132676295201801020006
# 6   CREDIT  01-02-2018    19.41  132676295201801020007
# 7    DEBIT  01-02-2018   -50.00  132676295201801020008
# 8    DEBIT  01-02-2018    -2.00  132676295201801020009
# 9    DEBIT  01-02-2018    -2.00  132676295201801020010
# 10   DEBIT  01-02-2018   -28.00  132676295201801020011
# 11   DEBIT  01-03-2018   -80.00  132676295201801030001
# 12   DEBIT  01-03-2018   -28.00  132676295201801030002
# 13  CREDIT  01-05-2018  2926.04  132676295201801050001
# 14   DEBIT  01-05-2018   -62.04  132676295201801050002
# 15   DEBIT  01-05-2018   -94.33  132676295201801050003
# 16   DEBIT  01-06-2018   -40.73  132676295201801060001
# 17   DEBIT  01-06-2018  -200.00  132676295201801060002
# 18   DEBIT  01-08-2018    -5.40  132676295201801080001
# 19   DEBIT  01-08-2018  -263.24  132676295201801080002
#
#                                 NAME  \
# 0              T'FER FROM ****716 S1
# 1            SHARE OVERDRAFT TFR FEE
# 2                     DEBIT PURCHASE
# 3                    DIVIDEND CREDIT
# 4              T'FER FROM ****716 S1
# 5   ReadyRefresh/ECHECKPAY/171229/CC
# 6              T'FER FROM ****716 S1
# 7   RELIANT RETAIL S/BILL PAYMT/1801
# 8                        O'DRAFT FEE
# 9                        O'DRAFT FEE
# 10             Privilege Pay Fee ACH
# 11   HCTRA EFT/EZTAGSTPPD/180101/PPD
# 12             Privilege Pay Fee ACH
# 13  CAMERON INTL COR/PAYROLL/010518/
# 14                    To Boo Account
# 15                        To Savings
# 16                    DEBIT PURCHASE
# 17            T'FER TO ****716 S75.2
# 18                    DEBIT PURCHASE
# 19                    DEBIT PURCHASE
#
#                                                  MEMO
# 0                                                 NaN
# 1                                                 NaN
# 2   THE GOOD FEET STORE 414-3278127 WI 73652090001...
# 3   Annual Percentage Yield Earned: 0.03% For the ...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                /PPD
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                  D
# 14                                                NaN
# 15                                                NaN
# 16  TST* MALEE S KITCHEN HOUSTON TX 800528200111 1...
# 17                                           eBANKING
# 18  APL* ITUNES.COM/BILL 866-712-7753 CA8006281004...
# 19  KOHL'S #1469 TOMBALL TX 800723600065 06520492 ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1022 entries, 0 to 1021
# Data columns (total 6 columns):
# TRNTYPE     1022 non-null object
# DTPOSTED    1022 non-null object
# TRANAMT     1022 non-null float64
# FITID       1022 non-null object
# NAME        1022 non-null object
# MEMO        787 non-null object
# dtypes: float64(1), object(5)
# memory usage: 48.0+ KB
# None
# C:/Users/Crystal/Desktop/Programs/dataset_repo/CDH_Test
# .csv
# C:/Users/Crystal/Desktop/Programs/dataset_repo/CDH_Test.csv
#     Length  Width  y  Species
# 0    4.955  1.015  0  Unknown
# 1    1.865  1.404  1      Dog
# 2    1.257  0.475  0      Cat
# 3    7.149  0.471  0  Unknown
# 4    2.899  1.378  1      Dog
# 5    7.188  2.222  0    Horse
# 6    1.155  1.283  0  Unknown
# 7    6.630  2.380  0    Horse
# 8    3.303  0.667  0  Unknown
# 9    6.244  1.596  0    Horse
# 10   1.640  1.036  1      Dog
# 11   7.179  1.836  0    Horse
# 12   4.970  0.589  0  Unknown
# 13   5.193  1.537  0  Unknown
# 14   1.520  1.581  1      Dog
# 15   4.928  1.977  0  Unknown
# 16   5.126  2.363  0  Unknown
# 17   4.944  1.593  0  Unknown
# 18   2.099  1.764  1      Dog
# 19   6.230  2.202  0    Horse
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 725 entries, 0 to 724
# Data columns (total 4 columns):
# Length     725 non-null float64
# Width      725 non-null float64
# y          725 non-null int64
# Species    725 non-null object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 22.7+ KB
# None

# %%
exit
