# %%
import pandas as pd
from pandas import set_option
import numpy as np
from numpy import set_printoptions
import datetime

# import tkinter


# import matplotlib.pyplot as plt
import matplotlib
matplotlib.use("TkAgg")
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg, NavigationToolbar2TkAgg
# Implement the default Matplotlib key bindings.
from matplotlib.backend_bases import key_press_handler
from matplotlib.figure import Figure
from pandas.plotting import scatter_matrix

import tkinter.ttk
from tkinter import filedialog
from tkinter import *


import os
import sys
sys.path.insert(0, "C:\\Users\\Crystal\\Desktop\\Programs\\my-modules-and-libraries")

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from scipy import stats

import my_gui_maker as gm
import data_wrangle as dw

# %%
def open_file_dialog():
    """(1-9-2018) Allows user to select dataset using file dialog window. The default directory is the 'dataset_repo'"""
    
    my_path='C:\\Users\\Crystal\\Desktop\\Programs\\dataset_repo'
    x=filedialog.askopenfilename(initialdir = my_path,title = "Data Repository",filetypes = (("all files","*.*"),("jpeg files","*.jpg"))) 
    filename, file_extension = os.path.splitext(x)
    print (filename) 
    print (file_extension)
    
    
    the_filename=filename.split('/')[-1]
    the_path=filename.partition('/'+the_filename)[0]
    the_extension=file_extension.split('.')[-1]
    
    the_file=filename+'.'+the_extension
    print (filename+'.'+the_extension)
    get_data(the_file)

# %%
def get_data (location,names=None):
#     the_data=pd.read_csv(location,usecols=names)
    
    data=pd.read_csv(location)
#     set_option('precision',3)
    data=data.round(3)

    data_info=dw.data_info(data)
    
    print(data.head(20))
    print(data.info())
    
    f1.the_tree(2,0,data_info)
    
    dlc=gm.My_Frame(root)
#     dlc.frame_header('Data Head',0,0)
    dlc.my_dlist_canvas(1,0,data.head())
    dlc.place_frame(3,0)

# %%
def bye_bye():
    root.destroy()
    sys.exit()

# %%
if __name__ == "__main__":
    
    root=gm.my_window(None)
    
    menubar=Menu(root)
    menubar.add_command(label="Get the Data", command=lambda: open_file_dialog())
    menubar.add_command(label="Exit", command=lambda: bye_bye())
    menubar.config(font=("Verdana", 14))
    
    root.config(menu=menubar)
    
    f1=gm.My_Frame(root)
    f1['bg']='grey'
    f1.frame_header('Data Info',0,0)
    f1.place_frame(0,0)
    
    root.mainloop()
# Out:
# C:/Users/Crystal/Desktop/Programs/dataset_repo/acs2015_census_tract_data
# .csv
# C:/Users/Crystal/Desktop/Programs/dataset_repo/acs2015_census_tract_data.csv
#     CensusTract    State   County  TotalPop   Men  Women  Hispanic  White  \
# 0    1001020100  Alabama  Autauga      1948   940   1008       0.9   87.4
# 1    1001020200  Alabama  Autauga      2156  1059   1097       0.8   40.4
# 2    1001020300  Alabama  Autauga      2968  1364   1604       0.0   74.5
# 3    1001020400  Alabama  Autauga      4423  2172   2251      10.5   82.8
# 4    1001020500  Alabama  Autauga     10763  4922   5841       0.7   68.5
# 5    1001020600  Alabama  Autauga      3851  1787   2064      13.1   72.9
# 6    1001020700  Alabama  Autauga      2761  1210   1551       3.8   74.5
# 7    1001020801  Alabama  Autauga      3187  1502   1685       1.3   84.0
# 8    1001020802  Alabama  Autauga     10915  5486   5429       1.4   89.5
# 9    1001020900  Alabama  Autauga      5668  2897   2771       0.4   85.5
# 10   1001021000  Alabama  Autauga      3286  1740   1546       0.8   73.3
# 11   1001021100  Alabama  Autauga      3295  1666   1629       0.5   44.5
# 12   1003010100  Alabama  Baldwin      3829  2157   1672       0.3   78.9
# 13   1003010200  Alabama  Baldwin      2869  1324   1545       1.3   86.0
# 14   1003010300  Alabama  Baldwin      7455  3462   3993       0.5   83.9
# 15   1003010400  Alabama  Baldwin      4537  2311   2226       4.9   88.7
# 16   1003010500  Alabama  Baldwin      5321  2711   2610       1.3   82.9
# 17   1003010600  Alabama  Baldwin      3398  1821   1577       3.5   34.0
# 18   1003010701  Alabama  Baldwin      7813  4098   3715       4.6   91.3
# 19   1003010703  Alabama  Baldwin     16099  8213   7886       5.8   84.6
#
#     Black  Native      ...       Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 0     7.7     0.3      ...        0.5          2.3         2.1         25.0
# 1    53.3     0.0      ...        0.0          0.7         0.0         23.4
# 2    18.6     0.5      ...        0.0          0.0         2.5         19.6
# 3     3.7     1.6      ...        0.0          2.6         1.6         25.3
# 4    24.8     0.0      ...        0.0          0.6         0.9         24.8
# 5    11.9     0.0      ...        0.0          6.0         4.5         19.8
# 6    19.7     0.0      ...        0.0          0.0         0.0         20.0
# 7    10.7     3.1      ...        0.0          1.7         5.9         24.3
# 8     8.4     0.0      ...        0.0          0.0         1.3         29.4
# 9    12.1     0.0      ...        0.0          1.2         2.1         32.9
# 10   24.7     1.3      ...        6.3          0.7         0.7         31.5
# 11   54.3     0.0      ...        1.3          3.2         2.6         32.6
# 12   17.8     2.2      ...        0.0          0.0         0.8         34.5
# 13   10.4     0.0      ...        0.6          0.0         1.9         30.3
# 14   13.6     0.4      ...        0.8          0.3         2.8         28.8
# 15    4.4     1.5      ...        1.0          1.1         2.9         32.7
# 16   12.9     0.1      ...        1.1          0.0         1.0         23.6
# 17   62.5     0.0      ...        1.0          0.9         0.7         20.4
# 18    2.8     0.2      ...        0.4          0.3         3.4         25.1
# 19    4.4     0.0      ...        0.1          1.6         2.5         31.8
#
#     Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0        943         77.1        18.3           4.6         0.0           5.4
# 1        753         77.0        16.9           6.1         0.0          13.3
# 2       1373         64.1        23.6          12.3         0.0           6.2
# 3       1782         75.7        21.2           3.1         0.0          10.8
# 4       5037         67.1        27.6           5.3         0.0           4.2
# 5       1560         79.4        14.7           5.8         0.0          10.9
# 6       1166         82.0        14.6           3.4         0.0          11.4
# 7       1502         78.1        14.8           7.1         0.0           8.2
# 8       4348         73.3        22.1           4.6         0.0           8.7
# 9       2485         77.9        15.2           6.9         0.0           7.2
# 10      1541         76.9        19.5           3.6         0.0           5.2
# 11      1496         70.7        24.7           4.6         0.0           7.3
# 12      1406         73.9        21.5           4.6         0.0          10.1
# 13      1221         78.0        13.9           8.1         0.0           8.5
# 14      3033         79.4        17.5           2.4         0.8           7.7
# 15      1790         80.6        11.4           8.0         0.0          10.7
# 16      2042         69.3        23.8           6.9         0.0           7.0
# 17      1392         71.7        23.9           4.5         0.0           5.7
# 18      3838         81.1        11.5           6.4         0.9           3.3
# 19      8843         80.1        16.1           3.8         0.0           2.2
#
# [20 rows x 37 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74001 entries, 0 to 74000
# Data columns (total 37 columns):
# CensusTract        74001 non-null int64
# State              74001 non-null object
# County             74001 non-null object
# TotalPop           74001 non-null int64
# Men                74001 non-null int64
# Women              74001 non-null int64
# Hispanic           73311 non-null float64
# White              73311 non-null float64
# Black              73311 non-null float64
# Native             73311 non-null float64
# Asian              73311 non-null float64
# Pacific            73311 non-null float64
# Citizen            74001 non-null int64
# Income             72901 non-null float64
# IncomeErr          72901 non-null float64
# IncomePerCap       73261 non-null float64
# IncomePerCapErr    73261 non-null float64
# Poverty            73166 non-null float64
# ChildPoverty       72883 non-null float64
# Professional       73194 non-null float64
# Service            73194 non-null float64
# Office             73194 non-null float64
# Construction       73194 non-null float64
# Production         73194 non-null float64
# Drive              73204 non-null float64
# Carpool            73204 non-null float64
# Transit            73204 non-null float64
# Walk               73204 non-null float64
# OtherTransp        73204 non-null float64
# WorkAtHome         73204 non-null float64
# MeanCommute        73052 non-null float64
# Employed           74001 non-null int64
# PrivateWork        73194 non-null float64
# PublicWork         73194 non-null float64
# SelfEmployed       73194 non-null float64
# FamilyWork         73194 non-null float64
# Unemployment       73199 non-null float64
# dtypes: float64(29), int64(6), object(2)
# memory usage: 20.9+ MB
# None
# you clicked on {'text': '0', 'image': '', 'values': ['int64', 'CensusTract', 0, 74001], 'open': 0, 'tags': ['blue']}
# Your header is  CensusTract
# The data type is  int64
# you clicked on {'text': '4', 'image': '', 'values': ['int64', 'Men', 0, 74001], 'open': 0, 'tags': ['blue']}
# Your header is  Men
# The data type is  int64
# you clicked on {'text': '2', 'image': '', 'values': ['object', 'County', 0, 74001], 'open': 0, 'tags': ['blue']}
# Your header is  County
# The data type is  object
# you clicked on {'text': '1', 'image': '', 'values': ['object', 'State', 0, 74001], 'open': 0, 'tags': ['blue']}
# Your header is  State
# The data type is  object
# you clicked on {'text': '4', 'image': '', 'values': ['int64', 'Men', 0, 74001], 'open': True, 'tags': ['blue']}
# Your header is  Men
# The data type is  int64
# you clicked on {'text': '6', 'image': '', 'values': ['float64', 'Hispanic', 690, 73311], 'open': 0, 'tags': ['blue']}
# Your header is  Hispanic
# The data type is  float64
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\Public\Programming\lib\site-packages\IPython\core\interactiveshell.py:2870: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
